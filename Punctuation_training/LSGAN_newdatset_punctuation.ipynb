# %%
# !pip install python-resize-image
# !pip install -U scipy==1.2.0
# !pip install python-archive
import numpy as np
from numpy.random import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from skimage import data, io, transform
import matplotlib.pyplot as plt
from archive import Archive
from archive import extract

tf.test.gpu_device_name()
# Out:
# Collecting python-resize-image
#   Downloading https://files.pythonhosted.org/packages/bc/89/008481c95551992e1a77503eba490b75fd17c0a98e33dd4dc39e0b99e5e8/python_resize_image-1.1.19-py2.py3-none-any.whl
# Requirement already satisfied: Pillow>=5.1.0 in /usr/local/lib/python3.6/dist-packages (from python-resize-image) (7.0.0)
# Requirement already satisfied: requests>=2.19.1 in /usr/local/lib/python3.6/dist-packages (from python-resize-image) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (3.0.4)
# Installing collected packages: python-resize-image
# Successfully installed python-resize-image-1.1.19
# Collecting scipy==1.2.0
#   Downloading https://files.pythonhosted.org/packages/67/e6/6d4edaceee6a110ecf6f318482f5229792f143e468b34a631f5a0899f56d/scipy-1.2.0-cp36-cp36m-manylinux1_x86_64.whl (26.6MB)
#      |████████████████████████████████| 26.6MB 112kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.2.0) (1.18.4)
# ERROR: umap-learn 0.4.2 has requirement scipy>=1.3.1, but you'll have scipy 1.2.0 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.2.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# Successfully installed scipy-1.2.0
# Collecting python-archive
#   Downloading https://files.pythonhosted.org/packages/4b/17/560776b5c88c0c665b54db9d076e7334b70fee5100a1bb52b18b92f9e123/python-archive-0.2.tar.gz
# Building wheels for collected packages: python-archive
#   Building wheel for python-archive (setup.py) ... done
#   Created wheel for python-archive: filename=python_archive-0.2-cp36-none-any.whl size=6473 sha256=6f266e75062478e5d27261b995fda7c99834fd8ce7cd52f5261f1b30ef739264
#   Stored in directory: /root/.cache/pip/wheels/3a/3b/c2/cde06bb709d37d647cc99a812cc1a06f2704d5feb20e97fee6
# Successfully built python-archive
# Installing collected packages: python-archive
# Successfully installed python-archive-0.2
# '/device:GPU:0'

# %%
from PIL import Image
from resizeimage import resizeimage

# %%
# !wget https://s3-eu-west-1.amazonaws.com/handwriting-curated-database/curated.tar.gz
# Out:
# --2020-05-14 05:38:38--  https://s3-eu-west-1.amazonaws.com/handwriting-curated-database/curated.tar.gz
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.101.51
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.101.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30058219 (29M) [application/x-gzip]
# Saving to: ‘curated.tar.gz’
#
# curated.tar.gz      100%[===================>]  28.67M  5.95MB/s    in 4.8s
#
# 2020-05-14 05:38:45 (5.95 MB/s) - ‘curated.tar.gz’ saved [30058219/30058219]

# %%
extract('curated.tar.gz', 'curated_data')

# %%
from __future__ import print_function

import pandas as pd
import cv2
from scipy.misc import imresize, imrotate, imsave

# display plots in this notebook
# %matplotlib inline

# set display defaults
plt.rcParams['figure.figsize'] = (10, 10) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray' 


path = 'curated_data'

# %%
from os import listdir
from os.path import isfile, join
punc = '!\"#$%&\'()*+,-./:;<=>?@[]^_`{|}~'
#lett = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
#num = '0123456789'
character_curated = [ord(c) for c in punc]
print([chr(i) for i in character_curated])

images = []
labels = []
for i in character_curated:
    path_img = path + '/curated/' + str(i) + '/'
    for file_name in [f for f in listdir(path_img) if isfile(join(path_img, f))]:
        img = cv2.imread(path_img + file_name, 0)
        img = cv2.resize(img,(28, 28), interpolation = cv2.INTER_AREA)
        images += [img]
        labels += [i]

images = np.array(images, dtype=np.uint8)
labels = np.array(labels, dtype=np.uint8)
print(images.shape)
print(labels.shape)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', ']', '^', '_', '`', '{', '|', '}', '~']
# (5975, 28, 28)
# (5975,)

# %%
plt.imshow(images[0])
print(labels[0])
# Out:
# 33

# %%
def define_discriminator(input_shape=(28, 28, 1), n_classes=31):
    # label input and embedding
    label_in = Input(shape=(1, ))
    print(label_in.shape)
    emb = Embedding(n_classes, 50)(label_in)
    print(emb.shape)
    label_h = Dense(input_shape[0] * input_shape[1])(emb)
    print(label_h.shape)
    re_label_h = Reshape((input_shape[0], input_shape[1], 1))(label_h)
    print(re_label_h.shape)
    # image input
    image_in = Input(shape=input_shape)
    # combine inputs
    merge = Concatenate()([image_in, re_label_h])
    # convnet
    h1 = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(merge)
    r1 = LeakyReLU(alpha=0.2)(h1)
    h2 = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(r1)
    r2 = LeakyReLU(alpha=0.2)(h2)
    # fully connected net
    fl = Flatten()(r2) 
    dr = Dropout(0.4)(fl)
    # output
    out = Dense(1, activation='sigmoid')(dr)
    # define and compile model
    model = Model([image_in, label_in], out)
    opt = Adam(lr=2e-4, beta_1=0.5)
    model.compile(loss='mse', optimizer=opt, metrics=['accuracy'])
    return model

# %%
def define_generator(latent_dim, n_classes=31):
    # label input and embedding
    label_in = Input(shape=(1, ))
    emb = Embedding(n_classes, 50)(label_in)
    label_h = Dense(7*7)(emb)
    re_label_h = Reshape((7, 7, 1))(label_h)
    # noisy image input
    noise_in = Input(shape=(latent_dim,))
    noise_h = Dense(128*7*7)(noise_in)
    noise_r = LeakyReLU(alpha=0.2)(noise_h)
    re_noise_r = Reshape((7, 7, 128))(noise_r)
    # combine inputs
    merge = Concatenate()([re_noise_r, re_label_h])
    # upsampling
    u1 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(merge)
    r1 = LeakyReLU(alpha=0.2)(u1)
    u2 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(r1)
    r2 = LeakyReLU(alpha=0.2)(u2)
    # output
    out = Conv2D(1, (7, 7), activation='tanh', padding='same')(r2)
    # define model
    model = Model([noise_in, label_in], out)
    return model

# %%
def define_gan(gen, dis):
    # discriminator shouldn't be trainable
    dis.trainable = False
    # get generator inputs and outputs
    gen_noise, gen_label = gen.input
    gen_output = gen.output
    print
    # feed to discriminator
    gan_output = dis([gen_output, gen_label])
    # define and compile GAN model
    model = Model([gen_noise, gen_label], gan_output)
    opt = Adam(lr=2e-4, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
def labels_updated(labels):
  for i in range(labels.shape[0]):
    #if labels[i] in range(65,91):
      #labels[i] -=65
    #if labels[i] in range(97,123):
      #labels[i]-=71
    #if labels[i] in range(48,58):
      #labels[i]+=4
    if labels[i] in range(33,48):
      labels[i] -=33
    if labels[i] in range(58,65):
      labels[i]-=43
    if labels[i] == 91:
      labels[i] = 22
    if labels[i] in range(93,97):
      labels[i]-=70
    if labels[i] in range(123,127):
      labels[i]-=96
  return labels

# %% [markdown]
#  if labels[i] in range(33,48):
#       labels[i]+=29
#     if labels[i] in range(58,65):
#       labels[i]+=19
#     if labels[i] == 91:
#       labels[i] = 84
#     if labels[i] in range(93,97):
#       labels[i]-=8
#     if labels[i] in range(123,127):
#       labels[i]-=34

# %%
def prepare_inputs(images, labels):
    if len(images.shape) > 2:
      images = np.squeeze(images)
    X = np.expand_dims(images, axis=-1)
    X = X.astype('float32')
    X = (X-127.5) / 127.5
    labels = labels_updated(labels)
    return [X, labels]
    
def generate_real_samples(images, labels, n_samples):
    rand_index = randint(0, images.shape[0], n_samples)
    X, labels = images[rand_index], labels[rand_index]
    y = np.ones((n_samples, 1)) * 0.9 # discriminator target label
    # label smoothing
    #ind = np.random.choice(list(range(len(y))), size=int(len(y) * 0.01), replace=False)
    #y[ind] = 1-y[ind]
    return [X, labels], y

def generate_latent_noise(latent_dim, n_samples, n_classes=31):
    xin = randn(latent_dim * n_samples)
    xin = xin.reshape(n_samples, latent_dim)
    labels = randint(0, n_classes, n_samples)  #  generator class label
    return xin, labels

def generate_fake_samples(gen, latent_dim, n_samples):
    zin, lin = generate_latent_noise(latent_dim, n_samples)
    images = gen.predict([zin, lin])
    y = np.zeros((n_samples, 1))  # discriminator target label
    # label smoothing
    #ind = np.random.choice(list(range(len(y))), size=int(len(y) * 0.01), replace=False)
    #y[ind] = 1-y[ind]
    return [images, lin], y

# %%
def train_gan(gen, dis, gan_model, images, labels, latent_dim, n_epochs=100, batch_size=128):
    batch_per_epoch = int(images.shape[0] / batch_size)
    half_batch = int(batch_size / 2)
    # enumerate epochs
    for i in range(n_epochs):
        for j in range(batch_per_epoch):
            # train discriminator on real images
            [X_real, labels_real], y_real = generate_real_samples(images, labels, half_batch)
            d_loss1, _ = dis.train_on_batch([X_real, labels_real], y_real)
            # train discriminator on generated images
            [X_fake, labels_fake], y_fake = generate_fake_samples(gen, latent_dim, half_batch)
            #d_loss2 = dis.evaluate([X_fake, labels_fake], y_fake)[0]
            #if d_loss2 > 0.5:
            d_loss2, _ = dis.train_on_batch([X_fake, labels_fake], y_fake)
            # prepare generator input
            [zin, label_in] = generate_latent_noise(latent_dim, batch_size)
            # invert labels for fake samples (prevent vanishing gradients)
            y_gan = np.ones((batch_size, 1))
            # label smoothing
            #ind = np.random.choice(list(range(len(y_gan))), size=int(len(y_gan) * 0.01), replace=False)
            #y_gan[ind] = 1-y_gan[ind]
            # update generator loss
            g_loss = gan_model.train_on_batch([zin, label_in], y_gan)
            # output losses
            if j % 50 == 0:
              print('Epoch {}, batch {}/{}:\tDiscriminator: real loss {}, fake loss {}\tGenerator: loss {}'
                  .format(i+1, j+1, batch_per_epoch, d_loss1, d_loss2, g_loss))
    # save the models
    gen.save('generator.h5')
    dis.save('discriminator.h5')
    gan_model.save('gan.h5')

# %%
#def labels_mapping():
#  labels_map = {i-65 :i for i in range(65, 91)}
#  labels_map.update({i-71 : i for i in range(97,123)})
#  return labels_map

# %%
latent_dim = 300
images, labels = prepare_inputs(images, labels)
print(images.shape, labels.shape)
#labels_map = labels_mapping()
dis = define_discriminator()
gen = define_generator(latent_dim)
gan_model = define_gan(gen, dis)
print("\nDiscriminator\n")
dis.summary()
print("\nGenerator\n")
gen.summary()
print("\nGAN\n")
gan_model.summary()
# Out:
# (5975, 28, 28, 1) (5975,)
# (None, 1)
# (None, 1, 50)
# (None, 1, 784)
# (None, 28, 28, 1)
#
# Discriminator
#
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 50)        1550        input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 784)       39984       embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 28, 28, 1)    0           dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 2)    0           input_2[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 14, 14, 64)   1216        concatenate[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 14, 14, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 64)     36928       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 7, 7, 64)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 3136)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            3137        dropout[0][0]
# ==================================================================================================
# Total params: 82,815
# Trainable params: 0
# Non-trainable params: 82,815
# __________________________________________________________________________________________________
#
# Generator
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 300)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6272)         1887872     input_4[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 50)        1550        input_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 6272)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 49)        2499        embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 7, 7, 128)    0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 7, 7, 1)      0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 129)    0           reshape_2[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 14, 14, 128)  264320      concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 14, 14, 128)  0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 28, 28, 128)  262272      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 28, 28, 128)  0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 1)    6273        leaky_re_lu_4[0][0]
# ==================================================================================================
# Total params: 2,424,786
# Trainable params: 2,424,786
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# GAN
#
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 300)]        0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6272)         1887872     input_4[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 50)        1550        input_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 6272)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 49)        2499        embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 7, 7, 128)    0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 7, 7, 1)      0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 7, 7, 129)    0           reshape_2[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 14, 14, 128)  264320      concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 14, 14, 128)  0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 28, 28, 128)  262272      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 28, 28, 128)  0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 1)    6273        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# model (Model)                   (None, 1)            82815       conv2d_2[0][0]
#                                                                  input_3[0][0]
# ==================================================================================================
# Total params: 2,507,601
# Trainable params: 2,424,786
# Non-trainable params: 82,815
# __________________________________________________________________________________________________

# %%
train_gan(gen, dis, gan_model, images, labels, latent_dim, n_epochs=400, batch_size=128)
# Out:
# Epoch 1, batch 1/46:	Discriminator: real loss 0.16982847452163696, fake loss 0.1837269365787506	Generator: loss 1.1614961624145508
# Epoch 2, batch 1/46:	Discriminator: real loss 0.1590016931295395, fake loss 0.1726558804512024	Generator: loss 1.022476315498352
# Epoch 3, batch 1/46:	Discriminator: real loss 0.18213871121406555, fake loss 0.12544360756874084	Generator: loss 1.188117265701294
# Epoch 4, batch 1/46:	Discriminator: real loss 0.134709894657135, fake loss 0.20058467984199524	Generator: loss 1.142197608947754
# Epoch 5, batch 1/46:	Discriminator: real loss 0.172193706035614, fake loss 0.15152119100093842	Generator: loss 1.231263279914856
# Epoch 6, batch 1/46:	Discriminator: real loss 0.15121132135391235, fake loss 0.17789721488952637	Generator: loss 1.1877740621566772
# Epoch 7, batch 1/46:	Discriminator: real loss 0.16004414856433868, fake loss 0.15212738513946533	Generator: loss 1.1724963188171387
# Epoch 8, batch 1/46:	Discriminator: real loss 0.15681490302085876, fake loss 0.17936652898788452	Generator: loss 1.1492571830749512
# Epoch 9, batch 1/46:	Discriminator: real loss 0.16014567017555237, fake loss 0.1476529836654663	Generator: loss 1.283377766609192
# Epoch 10, batch 1/46:	Discriminator: real loss 0.1276877522468567, fake loss 0.17614531517028809	Generator: loss 1.1281278133392334
# Epoch 11, batch 1/46:	Discriminator: real loss 0.16687849164009094, fake loss 0.17262011766433716	Generator: loss 1.116353154182434
# Epoch 12, batch 1/46:	Discriminator: real loss 0.1805659979581833, fake loss 0.1606161892414093	Generator: loss 1.1881933212280273
# Epoch 13, batch 1/46:	Discriminator: real loss 0.16509956121444702, fake loss 0.17994648218154907	Generator: loss 1.1359095573425293
# Epoch 14, batch 1/46:	Discriminator: real loss 0.17052510380744934, fake loss 0.16359345614910126	Generator: loss 1.1932133436203003
# Epoch 15, batch 1/46:	Discriminator: real loss 0.15216019749641418, fake loss 0.2142268717288971	Generator: loss 1.1469435691833496
# Epoch 16, batch 1/46:	Discriminator: real loss 0.17353573441505432, fake loss 0.17054185271263123	Generator: loss 1.210623860359192
# Epoch 17, batch 1/46:	Discriminator: real loss 0.1605895608663559, fake loss 0.16601622104644775	Generator: loss 1.0492678880691528
# Epoch 18, batch 1/46:	Discriminator: real loss 0.16369223594665527, fake loss 0.17469695210456848	Generator: loss 1.14238440990448
# Epoch 19, batch 1/46:	Discriminator: real loss 0.15455572307109833, fake loss 0.16889309883117676	Generator: loss 1.1145567893981934
# Epoch 20, batch 1/46:	Discriminator: real loss 0.1711573451757431, fake loss 0.1627141833305359	Generator: loss 1.140254259109497
# Epoch 21, batch 1/46:	Discriminator: real loss 0.21768273413181305, fake loss 0.13771288096904755	Generator: loss 1.1120051145553589
# Epoch 22, batch 1/46:	Discriminator: real loss 0.15894566476345062, fake loss 0.15875500440597534	Generator: loss 1.2148652076721191
# Epoch 23, batch 1/46:	Discriminator: real loss 0.16164147853851318, fake loss 0.12211988866329193	Generator: loss 1.1717225313186646
# Epoch 24, batch 1/46:	Discriminator: real loss 0.12728753685951233, fake loss 0.15093982219696045	Generator: loss 1.0806145668029785
# Epoch 25, batch 1/46:	Discriminator: real loss 0.14830735325813293, fake loss 0.16457536816596985	Generator: loss 1.1718575954437256
# Epoch 26, batch 1/46:	Discriminator: real loss 0.15421301126480103, fake loss 0.14187714457511902	Generator: loss 1.10518479347229
# Epoch 27, batch 1/46:	Discriminator: real loss 0.13715708255767822, fake loss 0.17476442456245422	Generator: loss 1.1727213859558105
# Epoch 28, batch 1/46:	Discriminator: real loss 0.18513277173042297, fake loss 0.16225847601890564	Generator: loss 1.0697202682495117
# Epoch 29, batch 1/46:	Discriminator: real loss 0.15817081928253174, fake loss 0.19885408878326416	Generator: loss 1.1311438083648682
# Epoch 30, batch 1/46:	Discriminator: real loss 0.19218318164348602, fake loss 0.15544991195201874	Generator: loss 1.1114344596862793
# Epoch 31, batch 1/46:	Discriminator: real loss 0.17527148127555847, fake loss 0.12801280617713928	Generator: loss 1.1176867485046387
# Epoch 32, batch 1/46:	Discriminator: real loss 0.15767613053321838, fake loss 0.18341897428035736	Generator: loss 1.1584328413009644
# Epoch 33, batch 1/46:	Discriminator: real loss 0.1599900871515274, fake loss 0.15489456057548523	Generator: loss 1.1983802318572998
# Epoch 34, batch 1/46:	Discriminator: real loss 0.13847187161445618, fake loss 0.15959635376930237	Generator: loss 1.1641201972961426
# Epoch 35, batch 1/46:	Discriminator: real loss 0.1550140082836151, fake loss 0.17165040969848633	Generator: loss 1.2523069381713867
# Epoch 36, batch 1/46:	Discriminator: real loss 0.1654166430234909, fake loss 0.1447134017944336	Generator: loss 1.1983277797698975
# Epoch 37, batch 1/46:	Discriminator: real loss 0.15131926536560059, fake loss 0.14819574356079102	Generator: loss 1.2107818126678467
# Epoch 38, batch 1/46:	Discriminator: real loss 0.17812323570251465, fake loss 0.17547687888145447	Generator: loss 1.1912834644317627
# Epoch 39, batch 1/46:	Discriminator: real loss 0.19382308423519135, fake loss 0.16280201077461243	Generator: loss 1.0883015394210815
# Epoch 40, batch 1/46:	Discriminator: real loss 0.15386229753494263, fake loss 0.15714897215366364	Generator: loss 1.0998178720474243
# Epoch 41, batch 1/46:	Discriminator: real loss 0.14780202507972717, fake loss 0.19565622508525848	Generator: loss 1.2566659450531006
# Epoch 42, batch 1/46:	Discriminator: real loss 0.13654440641403198, fake loss 0.12452861666679382	Generator: loss 1.1819212436676025
# Epoch 43, batch 1/46:	Discriminator: real loss 0.15696902573108673, fake loss 0.19241803884506226	Generator: loss 1.1993666887283325
# Epoch 44, batch 1/46:	Discriminator: real loss 0.1609317660331726, fake loss 0.16647878289222717	Generator: loss 1.2377523183822632
# Epoch 45, batch 1/46:	Discriminator: real loss 0.16150490939617157, fake loss 0.1902228742837906	Generator: loss 1.1291221380233765
# Epoch 46, batch 1/46:	Discriminator: real loss 0.15934816002845764, fake loss 0.13056695461273193	Generator: loss 1.1408791542053223
# Epoch 47, batch 1/46:	Discriminator: real loss 0.20002397894859314, fake loss 0.17575934529304504	Generator: loss 1.1245741844177246
# Epoch 382, batch 1/46:	Discriminator: real loss 0.1688530594110489, fake loss 0.1637784242630005	Generator: loss 1.2159849405288696
# Epoch 383, batch 1/46:	Discriminator: real loss 0.18907707929611206, fake loss 0.10516133904457092	Generator: loss 1.3188279867172241
# Epoch 384, batch 1/46:	Discriminator: real loss 0.11976046860218048, fake loss 0.1341090202331543	Generator: loss 1.2749558687210083
# Epoch 385, batch 1/46:	Discriminator: real loss 0.14778375625610352, fake loss 0.14148810505867004	Generator: loss 1.1621763706207275
# Epoch 386, batch 1/46:	Discriminator: real loss 0.19025807082653046, fake loss 0.15310080349445343	Generator: loss 1.3081477880477905
# Epoch 387, batch 1/46:	Discriminator: real loss 0.12801098823547363, fake loss 0.1514359414577484	Generator: loss 1.2664544582366943
# Epoch 388, batch 1/46:	Discriminator: real loss 0.14722281694412231, fake loss 0.14449027180671692	Generator: loss 1.3801462650299072
# Epoch 389, batch 1/46:	Discriminator: real loss 0.11545663326978683, fake loss 0.15702605247497559	Generator: loss 1.2964458465576172
# Epoch 390, batch 1/46:	Discriminator: real loss 0.1475847363471985, fake loss 0.1701144278049469	Generator: loss 1.2858399152755737
# Epoch 391, batch 1/46:	Discriminator: real loss 0.20109739899635315, fake loss 0.15929149091243744	Generator: loss 1.3184953927993774
# Epoch 392, batch 1/46:	Discriminator: real loss 0.17576834559440613, fake loss 0.12275326251983643	Generator: loss 1.2633106708526611
# Epoch 393, batch 1/46:	Discriminator: real loss 0.15244810283184052, fake loss 0.1720932573080063	Generator: loss 1.2523568868637085
# Epoch 394, batch 1/46:	Discriminator: real loss 0.1544708013534546, fake loss 0.18775133788585663	Generator: loss 1.2442678213119507
# Epoch 395, batch 1/46:	Discriminator: real loss 0.16911301016807556, fake loss 0.14518339931964874	Generator: loss 1.3328756093978882
# Epoch 396, batch 1/46:	Discriminator: real loss 0.14032673835754395, fake loss 0.18310052156448364	Generator: loss 1.2520124912261963
# Epoch 397, batch 1/46:	Discriminator: real loss 0.14507077634334564, fake loss 0.1803392767906189	Generator: loss 1.304634690284729
# Epoch 398, batch 1/46:	Discriminator: real loss 0.16567298769950867, fake loss 0.15885190665721893	Generator: loss 1.3104853630065918
# Epoch 399, batch 1/46:	Discriminator: real loss 0.1413610428571701, fake loss 0.16803200542926788	Generator: loss 1.2479289770126343
# Epoch 400, batch 1/46:	Discriminator: real loss 0.17888817191123962, fake loss 0.15795296430587769	Generator: loss 1.2513539791107178

# %%
def show_generated(examples, n, c):
  fig = plt.figure(figsize=(c, n))
  for i in range(n*c):
    img = fig.add_subplot(n, c, i+1)
    plt.axis('off')
    plt.imshow(examples[i,:,:,0], cmap='gray_r')
  plt.show()

n = 10
c = 31

model = load_model('generator.h5')
noise, _ = generate_latent_noise(latent_dim, n*c)
labs = np.asarray([x for _ in range(n) for x in range(c)])

X = model.predict([noise, labs])
# scale from [-1, 1] to [0, 1]
X = (X + 1) / 2.0
x = np.squeeze(X[0])
plt.imshow(x)

show_generated(X, n, c)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from google.colab import files

dflag = True
if dflag:
  files.download('gan.h5')
  files.download('generator.h5')
  files.download('discriminator.h5')
