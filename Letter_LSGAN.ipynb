# %% [markdown]
# <h1>Handwriting Letter GAN</h1>
#
# <h3>Links</h3>
# <ul>
#     <li><a href=https://machinelearningmastery.com/how-to-develop-a-conditional-generative-adversarial-network-from-scratch/>cGAN Code</a></li>
#     <li><a href=https://keras.io/getting-started/functional-api-guide/>Keras Functional API</a></li>
#     <li><a href=<li><a href=https://arxiv.org/pdf/1702.05373.pdf>EMNIST Dataset Paper</a></li>
# </ul>

# %%
# !pip install emnist

import numpy as np
from numpy.random import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from emnist import *
from skimage import data, io, transform
import matplotlib.pyplot as plt

tf.test.gpu_device_name()
# Out:
# Requirement already satisfied: emnist in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from emnist) (1.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from emnist) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2.9)
# '/device:GPU:0'

# %%
list_datasets()
# Out:
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %%
images, labels = extract_training_samples('byclass')
print(images.shape, labels.shape)

# reduce the number of images per class
im, la = [], []
for c in range(62):
  lc = np.where(labels==c)[0] # index of label of that class
  # print(len(lc))
  imc, lac = images[lc][:500], labels[lc][:500] # min images per class = 1896
  im.extend(imc)
  la.extend(lac)
  # print(len(im), len(la))

images, labels = np.asarray(im), np.asarray(la)

print(images.shape, labels.shape)
plt.imshow(images[0])
print(labels[0])
# Out:
# (697932, 28, 28) (697932,)
# (31000, 28, 28) (31000,)
# 0

# %%
def define_discriminator(input_shape=(28, 28, 1), n_classes=62):
    # label input and embedding
    label_in = Input(shape=(1, ))
    emb = Embedding(n_classes, 50)(label_in)
    label_h = Dense(input_shape[0] * input_shape[1])(emb)
    re_label_h = Reshape((input_shape[0], input_shape[1], 1))(label_h)
    # image input
    image_in = Input(shape=input_shape)
    # combine inputs
    merge = Concatenate()([image_in, re_label_h])
    # convnet
    h1 = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(merge)
    r1 = LeakyReLU(alpha=0.2)(h1)
    h2 = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(r1)
    r2 = LeakyReLU(alpha=0.2)(h2)
    # fully connected net
    fl = Flatten()(r2) 
    dr = Dropout(0.4)(fl)
    # output
    out = Dense(1, activation='sigmoid')(dr)
    # define and compile model
    model = Model([image_in, label_in], out)
    opt = Adam(lr=2e-4, beta_1=0.5)
    model.compile(loss='mse', optimizer=opt, metrics=['accuracy'])
    return model

# %%
def define_generator(latent_dim, n_classes=62):
    # label input and embedding
    label_in = Input(shape=(1, ))
    emb = Embedding(n_classes, 50)(label_in)
    label_h = Dense(7*7)(emb)
    re_label_h = Reshape((7, 7, 1))(label_h)
    # noisy image input
    noise_in = Input(shape=(latent_dim,))
    noise_h = Dense(128*7*7)(noise_in)
    noise_r = LeakyReLU(alpha=0.2)(noise_h)
    re_noise_r = Reshape((7, 7, 128))(noise_r)
    # combine inputs
    merge = Concatenate()([re_noise_r, re_label_h])
    # upsampling
    u1 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(merge)
    r1 = LeakyReLU(alpha=0.2)(u1)
    u2 = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(r1)
    r2 = LeakyReLU(alpha=0.2)(u2)
    # output
    out = Conv2D(1, (7, 7), activation='tanh', padding='same')(r2)
    # define model
    model = Model([noise_in, label_in], out)
    return model

# %%
def define_gan(gen, dis):
    # discriminator shouldn't be trainable
    dis.trainable = False
    # get generator inputs and outputs
    gen_noise, gen_label = gen.input
    gen_output = gen.output
    # feed to discriminator
    gan_output = dis([gen_output, gen_label])
    # define and compile GAN model
    model = Model([gen_noise, gen_label], gan_output)
    opt = Adam(lr=2e-4, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
def prepare_inputs(images, labels):
    if len(images.shape) > 2:
      images = np.squeeze(images)
    X = np.expand_dims(images, axis=-1)
    X = X.astype('float32')
    X = (X-127.5) / 127.5
    return [X, labels]
    
def generate_real_samples(images, labels, n_samples):
    rand_index = randint(0, images.shape[0], n_samples)
    X, labels = images[rand_index], labels[rand_index]
    y = np.ones((n_samples, 1)) * 0.9 # discriminator target label
    # label smoothing
    #ind = np.random.choice(list(range(len(y))), size=int(len(y) * 0.01), replace=False)
    #y[ind] = 1-y[ind]
    return [X, labels], y

def generate_latent_noise(latent_dim, n_samples, n_classes=62):
    xin = randn(latent_dim * n_samples)
    xin = xin.reshape(n_samples, latent_dim)
    labels = randint(0, n_classes, n_samples)  #  generator class label
    return xin, labels

def generate_fake_samples(gen, latent_dim, n_samples):
    zin, lin = generate_latent_noise(latent_dim, n_samples)
    images = gen.predict([zin, lin])
    y = np.zeros((n_samples, 1))  # discriminator target label
    # label smoothing
    #ind = np.random.choice(list(range(len(y))), size=int(len(y) * 0.01), replace=False)
    #y[ind] = 1-y[ind]
    return [images, lin], y

# %%
def train_gan(gen, dis, gan_model, images, labels, latent_dim, n_epochs=100, batch_size=128):
    batch_per_epoch = int(images.shape[0] / batch_size)
    half_batch = int(batch_size / 2)
    # enumerate epochs
    for i in range(n_epochs):
        for j in range(batch_per_epoch):
            # train discriminator on real images
            [X_real, labels_real], y_real = generate_real_samples(images, labels, half_batch)
            d_loss1, _ = dis.train_on_batch([X_real, labels_real], y_real)
            # train discriminator on generated images
            [X_fake, labels_fake], y_fake = generate_fake_samples(gen, latent_dim, half_batch)
            #d_loss2 = dis.evaluate([X_fake, labels_fake], y_fake)[0]
            #if d_loss2 > 0.5:
            d_loss2, _ = dis.train_on_batch([X_fake, labels_fake], y_fake)
            # prepare generator input
            [zin, label_in] = generate_latent_noise(latent_dim, batch_size)
            # invert labels for fake samples (prevent vanishing gradients)
            y_gan = np.ones((batch_size, 1))
            # label smoothing
            #ind = np.random.choice(list(range(len(y_gan))), size=int(len(y_gan) * 0.01), replace=False)
            #y_gan[ind] = 1-y_gan[ind]
            # update generator loss
            for _ in range(1):
              g_loss = gan_model.train_on_batch([zin, label_in], y_gan)
            # output losses
            if j % 50 == 0:
              print('Epoch {}, batch {}/{}:\tDiscriminator: real loss {}, fake loss {}\tGenerator: loss {}'
                  .format(i+1, j+1, batch_per_epoch, d_loss1, d_loss2, g_loss))
    # save the models
    gen.save('generator.h5')
    dis.save('discriminator.h5')
    gan_model.save('gan.h5')

# %%
latent_dim = 100
images, labels = prepare_inputs(images, labels)
print(images.shape, labels.shape)
dis = define_discriminator()
gen = define_generator(latent_dim)
gan_model = define_gan(gen, dis)
print("\nDiscriminator\n")
dis.summary()
print("\nGenerator\n")
gen.summary()
print("\nGAN\n")
gan_model.summary()
# Out:
# (31000, 28, 28, 1) (31000,)
#
# Discriminator
#
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 50)        3100        input_5[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 784)       39984       embedding_2[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 28, 28, 1)    0           dense_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 2)    0           input_6[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   1216        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 14, 14, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 64)     36928       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 7, 7, 64)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3136)         0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 3136)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            3137        dropout_1[0][0]
# ==================================================================================================
# Total params: 84,365
# Trainable params: 0
# Non-trainable params: 84,365
# __________________________________________________________________________________________________
#
# Generator
#
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 6272)         633472      input_8[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 50)        3100        input_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 6272)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 49)        2499        embedding_3[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 7, 7, 128)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 7, 7, 1)      0           dense_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 7, 7, 129)    0           reshape_5[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 14, 14, 128)  264320      concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 14, 14, 128)  0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 28, 28, 128)  262272      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 28, 28, 128)  0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 1)    6273        leaky_re_lu_9[0][0]
# ==================================================================================================
# Total params: 1,171,936
# Trainable params: 1,171,936
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# GAN
#
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 6272)         633472      input_8[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 50)        3100        input_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 6272)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 49)        2499        embedding_3[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 7, 7, 128)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 7, 7, 1)      0           dense_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 7, 7, 129)    0           reshape_5[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 14, 14, 128)  264320      concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 14, 14, 128)  0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 28, 28, 128)  262272      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 28, 28, 128)  0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 1)    6273        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 1)            84365       conv2d_5[0][0]
#                                                                  input_7[0][0]
# ==================================================================================================
# Total params: 1,256,301
# Trainable params: 1,171,936
# Non-trainable params: 84,365
# __________________________________________________________________________________________________

# %%
train_gan(gen, dis, gan_model, images, labels, latent_dim, n_epochs=50, batch_size=128)
# Out:
# Epoch 1, batch 1/242:	Discriminator: real loss 0.19450533390045166, fake loss 0.17840436100959778	Generator: loss 0.900916337966919
# Epoch 1, batch 51/242:	Discriminator: real loss 0.18602436780929565, fake loss 0.18937323987483978	Generator: loss 0.879059910774231
# Epoch 1, batch 101/242:	Discriminator: real loss 0.20433717966079712, fake loss 0.2017882615327835	Generator: loss 0.8968122601509094
# Epoch 1, batch 151/242:	Discriminator: real loss 0.18009163439273834, fake loss 0.2049567699432373	Generator: loss 0.9439263939857483
# Epoch 1, batch 201/242:	Discriminator: real loss 0.1978415548801422, fake loss 0.19723641872406006	Generator: loss 0.9067788124084473
# Epoch 2, batch 1/242:	Discriminator: real loss 0.18182724714279175, fake loss 0.1729286164045334	Generator: loss 0.937781810760498
# Epoch 2, batch 51/242:	Discriminator: real loss 0.18763969838619232, fake loss 0.1957322061061859	Generator: loss 0.9093680381774902
# Epoch 2, batch 101/242:	Discriminator: real loss 0.1705855131149292, fake loss 0.19054014980793	Generator: loss 0.8922346830368042
# Epoch 2, batch 151/242:	Discriminator: real loss 0.20314767956733704, fake loss 0.19003713130950928	Generator: loss 0.8741321563720703
# Epoch 2, batch 201/242:	Discriminator: real loss 0.19432054460048676, fake loss 0.18371698260307312	Generator: loss 0.8757486343383789
# Epoch 3, batch 1/242:	Discriminator: real loss 0.17817863821983337, fake loss 0.19368988275527954	Generator: loss 0.9187837839126587
# Epoch 3, batch 51/242:	Discriminator: real loss 0.18939533829689026, fake loss 0.2026292085647583	Generator: loss 0.8823180794715881
# Epoch 3, batch 101/242:	Discriminator: real loss 0.17944689095020294, fake loss 0.18630661070346832	Generator: loss 0.9503087997436523
# Epoch 3, batch 151/242:	Discriminator: real loss 0.1884402185678482, fake loss 0.22050747275352478	Generator: loss 0.8795278072357178
# Epoch 3, batch 201/242:	Discriminator: real loss 0.1732938289642334, fake loss 0.17030508816242218	Generator: loss 0.8921814560890198
# Epoch 4, batch 1/242:	Discriminator: real loss 0.19907927513122559, fake loss 0.185147225856781	Generator: loss 0.9304500818252563
# Epoch 4, batch 51/242:	Discriminator: real loss 0.19052791595458984, fake loss 0.1971275955438614	Generator: loss 0.9327040314674377
# Epoch 4, batch 101/242:	Discriminator: real loss 0.20368197560310364, fake loss 0.18897196650505066	Generator: loss 0.8988129496574402
# Epoch 4, batch 151/242:	Discriminator: real loss 0.19646672904491425, fake loss 0.19415247440338135	Generator: loss 0.9452489614486694
# Epoch 4, batch 201/242:	Discriminator: real loss 0.1894947588443756, fake loss 0.183287113904953	Generator: loss 0.9160310626029968
# Epoch 5, batch 1/242:	Discriminator: real loss 0.19679749011993408, fake loss 0.1705215871334076	Generator: loss 0.9032241106033325
# Epoch 5, batch 51/242:	Discriminator: real loss 0.15974700450897217, fake loss 0.18118035793304443	Generator: loss 0.9399410486221313
# Epoch 5, batch 101/242:	Discriminator: real loss 0.20290738344192505, fake loss 0.21021094918251038	Generator: loss 0.906916618347168
# Epoch 5, batch 151/242:	Discriminator: real loss 0.1909167766571045, fake loss 0.18290649354457855	Generator: loss 0.9018023610115051
# Epoch 5, batch 201/242:	Discriminator: real loss 0.1854425072669983, fake loss 0.20898714661598206	Generator: loss 0.8970888257026672
# Epoch 6, batch 1/242:	Discriminator: real loss 0.20297399163246155, fake loss 0.17884153127670288	Generator: loss 0.9376257061958313
# Epoch 6, batch 51/242:	Discriminator: real loss 0.18805065751075745, fake loss 0.1796807497739792	Generator: loss 0.8817890882492065
# Epoch 6, batch 101/242:	Discriminator: real loss 0.19783180952072144, fake loss 0.16961941123008728	Generator: loss 0.8928951621055603
# Epoch 6, batch 151/242:	Discriminator: real loss 0.17239806056022644, fake loss 0.18732920289039612	Generator: loss 0.8887637853622437
# Epoch 6, batch 201/242:	Discriminator: real loss 0.1859073042869568, fake loss 0.19197632372379303	Generator: loss 0.9183959364891052
# Epoch 7, batch 1/242:	Discriminator: real loss 0.20158743858337402, fake loss 0.19613048434257507	Generator: loss 0.9172549247741699
# Epoch 7, batch 51/242:	Discriminator: real loss 0.18170112371444702, fake loss 0.17414814233779907	Generator: loss 0.9432258009910583
# Epoch 7, batch 101/242:	Discriminator: real loss 0.2086350917816162, fake loss 0.1783393919467926	Generator: loss 0.8994088768959045
# Epoch 7, batch 151/242:	Discriminator: real loss 0.18800300359725952, fake loss 0.18874898552894592	Generator: loss 0.9322441816329956
# Epoch 7, batch 201/242:	Discriminator: real loss 0.20061154663562775, fake loss 0.20192740857601166	Generator: loss 0.9292871952056885
# Epoch 8, batch 1/242:	Discriminator: real loss 0.19016247987747192, fake loss 0.18276405334472656	Generator: loss 0.8904876112937927
# Epoch 8, batch 51/242:	Discriminator: real loss 0.20080646872520447, fake loss 0.17614853382110596	Generator: loss 0.9477384090423584
# Epoch 8, batch 101/242:	Discriminator: real loss 0.21003229916095734, fake loss 0.19228212535381317	Generator: loss 0.8875911831855774
# Epoch 8, batch 151/242:	Discriminator: real loss 0.20579704642295837, fake loss 0.18253472447395325	Generator: loss 0.8935909271240234
# Epoch 8, batch 201/242:	Discriminator: real loss 0.18523189425468445, fake loss 0.19650718569755554	Generator: loss 0.8952249884605408
# Epoch 9, batch 1/242:	Discriminator: real loss 0.18884336948394775, fake loss 0.18423596024513245	Generator: loss 0.9176572561264038
# Epoch 9, batch 51/242:	Discriminator: real loss 0.18787209689617157, fake loss 0.20339661836624146	Generator: loss 0.9021857380867004
# Epoch 9, batch 101/242:	Discriminator: real loss 0.1924358755350113, fake loss 0.18122267723083496	Generator: loss 0.9224055409431458
# Epoch 9, batch 151/242:	Discriminator: real loss 0.18398669362068176, fake loss 0.18527033925056458	Generator: loss 0.9483112096786499
# Epoch 9, batch 201/242:	Discriminator: real loss 0.18614500761032104, fake loss 0.1887620985507965	Generator: loss 0.9237815141677856
# Epoch 10, batch 1/242:	Discriminator: real loss 0.22756415605545044, fake loss 0.17616578936576843	Generator: loss 0.8781815767288208
# Epoch 10, batch 51/242:	Discriminator: real loss 0.18649308383464813, fake loss 0.17172382771968842	Generator: loss 0.930728554725647
# Epoch 10, batch 101/242:	Discriminator: real loss 0.1921907663345337, fake loss 0.1904962658882141	Generator: loss 0.9452020525932312
# Epoch 10, batch 151/242:	Discriminator: real loss 0.19769111275672913, fake loss 0.2052212357521057	Generator: loss 0.9396522045135498
# Epoch 10, batch 201/242:	Discriminator: real loss 0.1866702288389206, fake loss 0.18576912581920624	Generator: loss 0.9193673133850098
# Epoch 11, batch 1/242:	Discriminator: real loss 0.21527090668678284, fake loss 0.18826478719711304	Generator: loss 0.9648380875587463
# Epoch 11, batch 51/242:	Discriminator: real loss 0.18329201638698578, fake loss 0.1937638372182846	Generator: loss 0.9072349667549133
# Epoch 11, batch 101/242:	Discriminator: real loss 0.1938171684741974, fake loss 0.1805584877729416	Generator: loss 0.902179479598999
# Epoch 11, batch 151/242:	Discriminator: real loss 0.184423565864563, fake loss 0.19666624069213867	Generator: loss 0.9045567512512207
# Epoch 11, batch 201/242:	Discriminator: real loss 0.2031012326478958, fake loss 0.20054291188716888	Generator: loss 0.9176058769226074
# Epoch 12, batch 1/242:	Discriminator: real loss 0.19273824989795685, fake loss 0.1928921639919281	Generator: loss 0.9243509769439697
# Epoch 12, batch 51/242:	Discriminator: real loss 0.1911310851573944, fake loss 0.2030075192451477	Generator: loss 0.932891845703125
# Epoch 12, batch 101/242:	Discriminator: real loss 0.2047135829925537, fake loss 0.1859647035598755	Generator: loss 0.908227264881134
# Epoch 12, batch 151/242:	Discriminator: real loss 0.1977723091840744, fake loss 0.2007337510585785	Generator: loss 0.8901655673980713
# Epoch 12, batch 201/242:	Discriminator: real loss 0.20342278480529785, fake loss 0.18179050087928772	Generator: loss 0.9699183702468872
# Epoch 13, batch 1/242:	Discriminator: real loss 0.19805863499641418, fake loss 0.1712808907032013	Generator: loss 0.9036860466003418
# Epoch 13, batch 51/242:	Discriminator: real loss 0.20513464510440826, fake loss 0.2000371813774109	Generator: loss 0.8881347179412842
# Epoch 13, batch 101/242:	Discriminator: real loss 0.19433684647083282, fake loss 0.16534040868282318	Generator: loss 0.9089773893356323
# Epoch 13, batch 151/242:	Discriminator: real loss 0.1799280047416687, fake loss 0.1864394247531891	Generator: loss 0.9064539670944214
# Epoch 13, batch 201/242:	Discriminator: real loss 0.2031552791595459, fake loss 0.18221718072891235	Generator: loss 0.9043341875076294
# Epoch 14, batch 1/242:	Discriminator: real loss 0.1955384463071823, fake loss 0.20026832818984985	Generator: loss 0.9011001586914062
# Epoch 14, batch 51/242:	Discriminator: real loss 0.21346181631088257, fake loss 0.1833222210407257	Generator: loss 0.9079024195671082
# Epoch 14, batch 101/242:	Discriminator: real loss 0.20312967896461487, fake loss 0.20147019624710083	Generator: loss 0.9454188346862793
# Epoch 14, batch 151/242:	Discriminator: real loss 0.20410585403442383, fake loss 0.18767768144607544	Generator: loss 0.9326441884040833
# Epoch 14, batch 201/242:	Discriminator: real loss 0.18010187149047852, fake loss 0.18588507175445557	Generator: loss 0.9259909391403198
# Epoch 15, batch 1/242:	Discriminator: real loss 0.18599234521389008, fake loss 0.17850364744663239	Generator: loss 0.9230296611785889
# Epoch 15, batch 51/242:	Discriminator: real loss 0.18932390213012695, fake loss 0.17580202221870422	Generator: loss 0.9259675741195679
# Epoch 15, batch 101/242:	Discriminator: real loss 0.18654784560203552, fake loss 0.16579139232635498	Generator: loss 0.9464997053146362
# Epoch 15, batch 151/242:	Discriminator: real loss 0.19248151779174805, fake loss 0.19353090226650238	Generator: loss 0.9142533540725708
# Epoch 15, batch 201/242:	Discriminator: real loss 0.20129545032978058, fake loss 0.19070303440093994	Generator: loss 0.9376891851425171
# Epoch 16, batch 1/242:	Discriminator: real loss 0.18102645874023438, fake loss 0.19211207330226898	Generator: loss 0.9024980664253235
# Epoch 16, batch 51/242:	Discriminator: real loss 0.19339120388031006, fake loss 0.17136110365390778	Generator: loss 0.9551666975021362
# Epoch 16, batch 101/242:	Discriminator: real loss 0.1814175695180893, fake loss 0.19753426313400269	Generator: loss 0.9621010422706604
# Epoch 16, batch 151/242:	Discriminator: real loss 0.183956116437912, fake loss 0.17654332518577576	Generator: loss 0.9168894290924072
# Epoch 16, batch 201/242:	Discriminator: real loss 0.19377651810646057, fake loss 0.20785462856292725	Generator: loss 0.9125136137008667
# Epoch 17, batch 1/242:	Discriminator: real loss 0.19691938161849976, fake loss 0.18730109930038452	Generator: loss 0.919960618019104
# Epoch 17, batch 51/242:	Discriminator: real loss 0.19077667593955994, fake loss 0.21904045343399048	Generator: loss 0.8860312104225159
# Epoch 17, batch 101/242:	Discriminator: real loss 0.19873136281967163, fake loss 0.17820954322814941	Generator: loss 0.9200889468193054
# Epoch 17, batch 151/242:	Discriminator: real loss 0.2075585424900055, fake loss 0.19761231541633606	Generator: loss 0.9515454769134521
# Epoch 17, batch 201/242:	Discriminator: real loss 0.1763109266757965, fake loss 0.19392651319503784	Generator: loss 0.9203338623046875
# Epoch 18, batch 1/242:	Discriminator: real loss 0.1871103048324585, fake loss 0.18309777975082397	Generator: loss 0.9047525525093079
# Epoch 18, batch 51/242:	Discriminator: real loss 0.20937855541706085, fake loss 0.20271626114845276	Generator: loss 0.9217679500579834
# Epoch 18, batch 101/242:	Discriminator: real loss 0.19798918068408966, fake loss 0.20920699834823608	Generator: loss 0.9038944244384766
# Epoch 18, batch 151/242:	Discriminator: real loss 0.19714020192623138, fake loss 0.17944218218326569	Generator: loss 0.919037401676178
# Epoch 18, batch 201/242:	Discriminator: real loss 0.17852061986923218, fake loss 0.18429800868034363	Generator: loss 0.9316267371177673
# Epoch 19, batch 1/242:	Discriminator: real loss 0.19776551425457, fake loss 0.1908458024263382	Generator: loss 0.9032207131385803
# Epoch 19, batch 51/242:	Discriminator: real loss 0.19853177666664124, fake loss 0.18778623640537262	Generator: loss 0.9053406715393066
# Epoch 19, batch 101/242:	Discriminator: real loss 0.20601272583007812, fake loss 0.19521477818489075	Generator: loss 0.9366068243980408
# Epoch 19, batch 151/242:	Discriminator: real loss 0.19510474801063538, fake loss 0.18426299095153809	Generator: loss 0.9203786849975586
# Epoch 19, batch 201/242:	Discriminator: real loss 0.2049863338470459, fake loss 0.1681213676929474	Generator: loss 0.8913087248802185
# Epoch 20, batch 1/242:	Discriminator: real loss 0.19234099984169006, fake loss 0.21028418838977814	Generator: loss 0.920725405216217
# Epoch 20, batch 51/242:	Discriminator: real loss 0.1919175386428833, fake loss 0.1784811019897461	Generator: loss 0.9535688161849976
# Epoch 20, batch 101/242:	Discriminator: real loss 0.17858660221099854, fake loss 0.17582044005393982	Generator: loss 0.9280452132225037
# Epoch 20, batch 151/242:	Discriminator: real loss 0.1965179145336151, fake loss 0.19424942135810852	Generator: loss 0.9109325408935547
# Epoch 20, batch 201/242:	Discriminator: real loss 0.19320853054523468, fake loss 0.1754140406847	Generator: loss 0.9137499332427979
# Epoch 21, batch 1/242:	Discriminator: real loss 0.18497955799102783, fake loss 0.19518792629241943	Generator: loss 0.8934794068336487
# Epoch 21, batch 51/242:	Discriminator: real loss 0.19342169165611267, fake loss 0.20018014311790466	Generator: loss 0.940405547618866
# Epoch 21, batch 101/242:	Discriminator: real loss 0.1850605309009552, fake loss 0.19749140739440918	Generator: loss 0.9307563304901123
# Epoch 21, batch 151/242:	Discriminator: real loss 0.2085893452167511, fake loss 0.2016598880290985	Generator: loss 0.9487897157669067
# Epoch 21, batch 201/242:	Discriminator: real loss 0.20796605944633484, fake loss 0.19681507349014282	Generator: loss 0.878461480140686
# Epoch 22, batch 1/242:	Discriminator: real loss 0.22899192571640015, fake loss 0.19375476241111755	Generator: loss 0.91819167137146
# Epoch 22, batch 51/242:	Discriminator: real loss 0.20289689302444458, fake loss 0.17626482248306274	Generator: loss 0.9189531803131104
# Epoch 22, batch 101/242:	Discriminator: real loss 0.20520249009132385, fake loss 0.2090933620929718	Generator: loss 0.9022111296653748
# Epoch 22, batch 151/242:	Discriminator: real loss 0.15956956148147583, fake loss 0.18418221175670624	Generator: loss 0.9409728646278381
# Epoch 22, batch 201/242:	Discriminator: real loss 0.19612541794776917, fake loss 0.18984471261501312	Generator: loss 0.9257498979568481
# Epoch 23, batch 1/242:	Discriminator: real loss 0.1846114695072174, fake loss 0.19600681960582733	Generator: loss 0.9418568015098572
# Epoch 23, batch 51/242:	Discriminator: real loss 0.20724458992481232, fake loss 0.1817794293165207	Generator: loss 0.9154168367385864
# Epoch 23, batch 101/242:	Discriminator: real loss 0.1725473701953888, fake loss 0.18240150809288025	Generator: loss 0.9225515127182007
# Epoch 23, batch 151/242:	Discriminator: real loss 0.1962718367576599, fake loss 0.19079089164733887	Generator: loss 0.9169933795928955
# Epoch 23, batch 201/242:	Discriminator: real loss 0.18615582585334778, fake loss 0.19237253069877625	Generator: loss 0.9005454182624817
# Epoch 24, batch 1/242:	Discriminator: real loss 0.18683955073356628, fake loss 0.18922147154808044	Generator: loss 0.875840425491333
# Epoch 24, batch 51/242:	Discriminator: real loss 0.18007688224315643, fake loss 0.1961667537689209	Generator: loss 0.9203699827194214
# Epoch 24, batch 101/242:	Discriminator: real loss 0.19716870784759521, fake loss 0.1676875352859497	Generator: loss 0.8857682347297668
# Epoch 24, batch 151/242:	Discriminator: real loss 0.18572689592838287, fake loss 0.20172353088855743	Generator: loss 0.9590249061584473
# Epoch 24, batch 201/242:	Discriminator: real loss 0.1835101842880249, fake loss 0.17386490106582642	Generator: loss 0.9307713508605957
# Epoch 25, batch 1/242:	Discriminator: real loss 0.2006618082523346, fake loss 0.18598300218582153	Generator: loss 0.9433237314224243
# Epoch 25, batch 51/242:	Discriminator: real loss 0.1993674337863922, fake loss 0.19788284599781036	Generator: loss 0.9257202744483948
# Epoch 25, batch 101/242:	Discriminator: real loss 0.17335675656795502, fake loss 0.19722631573677063	Generator: loss 0.8933907151222229
# Epoch 25, batch 151/242:	Discriminator: real loss 0.1807079017162323, fake loss 0.1763240396976471	Generator: loss 0.9233770370483398
# Epoch 25, batch 201/242:	Discriminator: real loss 0.20386993885040283, fake loss 0.18699131906032562	Generator: loss 0.9118687510490417
# Epoch 26, batch 1/242:	Discriminator: real loss 0.18238399922847748, fake loss 0.17883630096912384	Generator: loss 0.9240626096725464
# Epoch 26, batch 51/242:	Discriminator: real loss 0.21842679381370544, fake loss 0.19281922280788422	Generator: loss 0.8671528697013855
# Epoch 26, batch 101/242:	Discriminator: real loss 0.2011660933494568, fake loss 0.19733133912086487	Generator: loss 0.9496443867683411
# Epoch 26, batch 151/242:	Discriminator: real loss 0.1924411654472351, fake loss 0.18801544606685638	Generator: loss 0.9094045162200928
# Epoch 26, batch 201/242:	Discriminator: real loss 0.20249462127685547, fake loss 0.19427797198295593	Generator: loss 0.94488924741745
# Epoch 27, batch 1/242:	Discriminator: real loss 0.1963731348514557, fake loss 0.18331696093082428	Generator: loss 0.9474793672561646
# Epoch 27, batch 51/242:	Discriminator: real loss 0.19042807817459106, fake loss 0.19796288013458252	Generator: loss 0.8773871660232544
# Epoch 27, batch 101/242:	Discriminator: real loss 0.1738116443157196, fake loss 0.2096080780029297	Generator: loss 0.9577064514160156
# Epoch 27, batch 151/242:	Discriminator: real loss 0.1690988689661026, fake loss 0.17847654223442078	Generator: loss 0.9079180955886841
# Epoch 27, batch 201/242:	Discriminator: real loss 0.19760999083518982, fake loss 0.1964299976825714	Generator: loss 0.9430702328681946
# Epoch 28, batch 1/242:	Discriminator: real loss 0.2191150188446045, fake loss 0.1726224422454834	Generator: loss 0.9093995094299316
# Epoch 28, batch 51/242:	Discriminator: real loss 0.187077134847641, fake loss 0.18214218318462372	Generator: loss 0.9237484931945801
# Epoch 28, batch 101/242:	Discriminator: real loss 0.19589152932167053, fake loss 0.19853901863098145	Generator: loss 0.8794326186180115
# Epoch 28, batch 151/242:	Discriminator: real loss 0.18539711833000183, fake loss 0.16856488585472107	Generator: loss 0.9169976711273193
# Epoch 28, batch 201/242:	Discriminator: real loss 0.1881335824728012, fake loss 0.17179417610168457	Generator: loss 0.8793279528617859
# Epoch 29, batch 1/242:	Discriminator: real loss 0.19448477029800415, fake loss 0.17863059043884277	Generator: loss 0.8834152817726135
# Epoch 29, batch 51/242:	Discriminator: real loss 0.20993898808956146, fake loss 0.17851224541664124	Generator: loss 0.9502067565917969
# Epoch 29, batch 101/242:	Discriminator: real loss 0.19970256090164185, fake loss 0.1760437935590744	Generator: loss 0.9219158887863159
# Epoch 29, batch 151/242:	Discriminator: real loss 0.19689291715621948, fake loss 0.20616067945957184	Generator: loss 0.9107436537742615
# Epoch 29, batch 201/242:	Discriminator: real loss 0.2122252732515335, fake loss 0.1894826591014862	Generator: loss 0.9179885387420654
# Epoch 30, batch 1/242:	Discriminator: real loss 0.20681098103523254, fake loss 0.1860249638557434	Generator: loss 0.9266447424888611
# Epoch 30, batch 51/242:	Discriminator: real loss 0.20079556107521057, fake loss 0.18647056818008423	Generator: loss 0.9183292388916016
# Epoch 30, batch 101/242:	Discriminator: real loss 0.1875571310520172, fake loss 0.19336357712745667	Generator: loss 0.8791298270225525
# Epoch 30, batch 151/242:	Discriminator: real loss 0.1906946301460266, fake loss 0.19795185327529907	Generator: loss 0.9023324251174927
# Epoch 30, batch 201/242:	Discriminator: real loss 0.19588233530521393, fake loss 0.18815666437149048	Generator: loss 0.9012185335159302
# Epoch 31, batch 1/242:	Discriminator: real loss 0.19589483737945557, fake loss 0.18957456946372986	Generator: loss 0.9182478189468384
# Epoch 31, batch 51/242:	Discriminator: real loss 0.19973216950893402, fake loss 0.19228801131248474	Generator: loss 0.9215289354324341
# Epoch 31, batch 101/242:	Discriminator: real loss 0.20747965574264526, fake loss 0.17595329880714417	Generator: loss 0.9047082662582397
# Epoch 31, batch 151/242:	Discriminator: real loss 0.18468455970287323, fake loss 0.18547604978084564	Generator: loss 0.9530236721038818
# Epoch 31, batch 201/242:	Discriminator: real loss 0.20334279537200928, fake loss 0.2056443691253662	Generator: loss 0.9417012929916382
# Epoch 32, batch 1/242:	Discriminator: real loss 0.19825655221939087, fake loss 0.18930262327194214	Generator: loss 0.94139564037323
# Epoch 32, batch 51/242:	Discriminator: real loss 0.190292090177536, fake loss 0.20313379168510437	Generator: loss 0.9524308443069458
# Epoch 32, batch 101/242:	Discriminator: real loss 0.18783429265022278, fake loss 0.20081865787506104	Generator: loss 0.9155495166778564
# Epoch 32, batch 151/242:	Discriminator: real loss 0.18420124053955078, fake loss 0.1936343014240265	Generator: loss 0.8757338523864746
# Epoch 32, batch 201/242:	Discriminator: real loss 0.18687760829925537, fake loss 0.19485409557819366	Generator: loss 0.9209502935409546
# Epoch 33, batch 1/242:	Discriminator: real loss 0.19440487027168274, fake loss 0.182991161942482	Generator: loss 0.9271726608276367
# Epoch 33, batch 51/242:	Discriminator: real loss 0.19008558988571167, fake loss 0.20358532667160034	Generator: loss 0.9255096316337585
# Epoch 33, batch 101/242:	Discriminator: real loss 0.19157405197620392, fake loss 0.18340888619422913	Generator: loss 0.9206417798995972
# Epoch 33, batch 151/242:	Discriminator: real loss 0.20301727950572968, fake loss 0.1966346800327301	Generator: loss 0.9343209266662598
# Epoch 33, batch 201/242:	Discriminator: real loss 0.1716844141483307, fake loss 0.1764906942844391	Generator: loss 0.9156017303466797
# Epoch 34, batch 1/242:	Discriminator: real loss 0.20378416776657104, fake loss 0.18905094265937805	Generator: loss 0.8790189027786255
# Epoch 34, batch 51/242:	Discriminator: real loss 0.18883240222930908, fake loss 0.19678650796413422	Generator: loss 0.9215747117996216
# Epoch 34, batch 101/242:	Discriminator: real loss 0.1934530884027481, fake loss 0.18873131275177002	Generator: loss 0.9288420677185059
# Epoch 34, batch 151/242:	Discriminator: real loss 0.20974166691303253, fake loss 0.17921069264411926	Generator: loss 0.9126416444778442
# Epoch 34, batch 201/242:	Discriminator: real loss 0.20645980536937714, fake loss 0.19022993743419647	Generator: loss 0.9582664966583252
# Epoch 35, batch 1/242:	Discriminator: real loss 0.20958611369132996, fake loss 0.18878506124019623	Generator: loss 0.9260851740837097
# Epoch 35, batch 51/242:	Discriminator: real loss 0.1856277734041214, fake loss 0.1767941117286682	Generator: loss 0.9538047313690186
# Epoch 35, batch 101/242:	Discriminator: real loss 0.21273505687713623, fake loss 0.1797291785478592	Generator: loss 0.9076732397079468
# Epoch 35, batch 151/242:	Discriminator: real loss 0.192316472530365, fake loss 0.18730273842811584	Generator: loss 0.8805273771286011
# Epoch 35, batch 201/242:	Discriminator: real loss 0.1738390028476715, fake loss 0.19626754522323608	Generator: loss 0.9251711368560791
# Epoch 36, batch 1/242:	Discriminator: real loss 0.1890895813703537, fake loss 0.17408740520477295	Generator: loss 0.9373379945755005
# Epoch 36, batch 51/242:	Discriminator: real loss 0.18097874522209167, fake loss 0.1875826120376587	Generator: loss 0.9273606538772583
# Epoch 36, batch 101/242:	Discriminator: real loss 0.1843138039112091, fake loss 0.19772952795028687	Generator: loss 0.9099297523498535
# Epoch 36, batch 151/242:	Discriminator: real loss 0.18894889950752258, fake loss 0.17387168109416962	Generator: loss 0.8899456262588501
# Epoch 36, batch 201/242:	Discriminator: real loss 0.20789092779159546, fake loss 0.16386759281158447	Generator: loss 0.93149733543396
# Epoch 37, batch 1/242:	Discriminator: real loss 0.1833210587501526, fake loss 0.18456315994262695	Generator: loss 0.8936368823051453
# Epoch 37, batch 51/242:	Discriminator: real loss 0.1761206090450287, fake loss 0.18987871706485748	Generator: loss 0.917190670967102
# Epoch 37, batch 101/242:	Discriminator: real loss 0.18819168210029602, fake loss 0.1847405731678009	Generator: loss 0.9330722093582153
# Epoch 37, batch 151/242:	Discriminator: real loss 0.1748008131980896, fake loss 0.1650797724723816	Generator: loss 0.9290003776550293
# Epoch 37, batch 201/242:	Discriminator: real loss 0.18771550059318542, fake loss 0.1797381043434143	Generator: loss 0.9429664611816406
# Epoch 38, batch 1/242:	Discriminator: real loss 0.17613926529884338, fake loss 0.1702948361635208	Generator: loss 0.926856279373169
# Epoch 38, batch 51/242:	Discriminator: real loss 0.19378983974456787, fake loss 0.1782836616039276	Generator: loss 0.8974646329879761
# Epoch 38, batch 101/242:	Discriminator: real loss 0.14807865023612976, fake loss 0.1888529360294342	Generator: loss 0.9533271789550781
# Epoch 38, batch 151/242:	Discriminator: real loss 0.18784256279468536, fake loss 0.1797303408384323	Generator: loss 0.9300187230110168
# Epoch 38, batch 201/242:	Discriminator: real loss 0.1984793245792389, fake loss 0.1849975287914276	Generator: loss 0.8725053668022156
# Epoch 39, batch 1/242:	Discriminator: real loss 0.18304164707660675, fake loss 0.18094316124916077	Generator: loss 0.916991114616394
# Epoch 39, batch 51/242:	Discriminator: real loss 0.19317886233329773, fake loss 0.1928206831216812	Generator: loss 0.9148446917533875
# Epoch 39, batch 101/242:	Discriminator: real loss 0.1737891137599945, fake loss 0.19925081729888916	Generator: loss 0.9026063680648804
# Epoch 39, batch 151/242:	Discriminator: real loss 0.1923815906047821, fake loss 0.19207510352134705	Generator: loss 0.9375134706497192
# Epoch 39, batch 201/242:	Discriminator: real loss 0.1772003173828125, fake loss 0.18240627646446228	Generator: loss 0.926296055316925
# Epoch 40, batch 1/242:	Discriminator: real loss 0.21646396815776825, fake loss 0.1874718964099884	Generator: loss 0.9307775497436523
# Epoch 40, batch 51/242:	Discriminator: real loss 0.1977936029434204, fake loss 0.17213132977485657	Generator: loss 0.9172375202178955
# Epoch 40, batch 101/242:	Discriminator: real loss 0.18852026760578156, fake loss 0.17448845505714417	Generator: loss 0.9148013591766357
# Epoch 40, batch 151/242:	Discriminator: real loss 0.1870736926794052, fake loss 0.18636855483055115	Generator: loss 0.8860547542572021
# Epoch 40, batch 201/242:	Discriminator: real loss 0.20781715214252472, fake loss 0.18084582686424255	Generator: loss 0.9384119510650635
# Epoch 41, batch 1/242:	Discriminator: real loss 0.1870843470096588, fake loss 0.1932387799024582	Generator: loss 0.9339033365249634
# Epoch 41, batch 51/242:	Discriminator: real loss 0.17172159254550934, fake loss 0.1807820051908493	Generator: loss 0.9330417513847351
# Epoch 41, batch 101/242:	Discriminator: real loss 0.1869584619998932, fake loss 0.18370047211647034	Generator: loss 0.9478710889816284
# Epoch 41, batch 151/242:	Discriminator: real loss 0.21022574603557587, fake loss 0.17011156678199768	Generator: loss 0.9202765226364136
# Epoch 41, batch 201/242:	Discriminator: real loss 0.19786065816879272, fake loss 0.18190646171569824	Generator: loss 0.9291492700576782
# Epoch 42, batch 1/242:	Discriminator: real loss 0.2042381465435028, fake loss 0.17950919270515442	Generator: loss 0.9158132076263428
# Epoch 42, batch 51/242:	Discriminator: real loss 0.19601503014564514, fake loss 0.1853325515985489	Generator: loss 0.9124692678451538
# Epoch 42, batch 101/242:	Discriminator: real loss 0.19596491754055023, fake loss 0.1799822747707367	Generator: loss 0.8937036395072937
# Epoch 42, batch 151/242:	Discriminator: real loss 0.16748464107513428, fake loss 0.17914512753486633	Generator: loss 0.9427205920219421
# Epoch 42, batch 201/242:	Discriminator: real loss 0.19754943251609802, fake loss 0.1893957257270813	Generator: loss 0.8989500999450684
# Epoch 43, batch 1/242:	Discriminator: real loss 0.18786786496639252, fake loss 0.17844244837760925	Generator: loss 0.9333381652832031
# Epoch 43, batch 51/242:	Discriminator: real loss 0.21506552398204803, fake loss 0.17360061407089233	Generator: loss 0.9339839220046997
# Epoch 43, batch 101/242:	Discriminator: real loss 0.18001261353492737, fake loss 0.17116430401802063	Generator: loss 0.9122145175933838
# Epoch 43, batch 151/242:	Discriminator: real loss 0.1955914944410324, fake loss 0.18090316653251648	Generator: loss 0.8832086324691772
# Epoch 43, batch 201/242:	Discriminator: real loss 0.21004609763622284, fake loss 0.1837327629327774	Generator: loss 0.9158998131752014
# Epoch 44, batch 1/242:	Discriminator: real loss 0.19275042414665222, fake loss 0.19601160287857056	Generator: loss 0.9273865222930908
# Epoch 44, batch 51/242:	Discriminator: real loss 0.20193307101726532, fake loss 0.17863473296165466	Generator: loss 0.9239349365234375
# Epoch 44, batch 101/242:	Discriminator: real loss 0.1913062036037445, fake loss 0.18780876696109772	Generator: loss 0.902262806892395
# Epoch 44, batch 151/242:	Discriminator: real loss 0.20662438869476318, fake loss 0.19155244529247284	Generator: loss 0.9188125133514404
# Epoch 44, batch 201/242:	Discriminator: real loss 0.19238010048866272, fake loss 0.19197963178157806	Generator: loss 0.9199566841125488
# Epoch 45, batch 1/242:	Discriminator: real loss 0.19342300295829773, fake loss 0.17779655754566193	Generator: loss 0.9366708993911743
# Epoch 45, batch 51/242:	Discriminator: real loss 0.18364380300045013, fake loss 0.1872977912425995	Generator: loss 0.9659698009490967
# Epoch 45, batch 101/242:	Discriminator: real loss 0.16583508253097534, fake loss 0.1914874017238617	Generator: loss 0.8867210745811462
# Epoch 45, batch 151/242:	Discriminator: real loss 0.18714216351509094, fake loss 0.18193422257900238	Generator: loss 0.9091256260871887
# Epoch 45, batch 201/242:	Discriminator: real loss 0.20375055074691772, fake loss 0.1944088488817215	Generator: loss 0.9051780700683594
# Epoch 46, batch 1/242:	Discriminator: real loss 0.1814233660697937, fake loss 0.18149150907993317	Generator: loss 0.9126766920089722
# Epoch 46, batch 51/242:	Discriminator: real loss 0.18354925513267517, fake loss 0.1804836094379425	Generator: loss 0.9102827906608582
# Epoch 46, batch 101/242:	Discriminator: real loss 0.21259011328220367, fake loss 0.1872311532497406	Generator: loss 0.9325951933860779
# Epoch 46, batch 151/242:	Discriminator: real loss 0.1649702787399292, fake loss 0.20442958176136017	Generator: loss 0.9080648422241211
# Epoch 46, batch 201/242:	Discriminator: real loss 0.19338327646255493, fake loss 0.2001398801803589	Generator: loss 0.8943837881088257
# Epoch 47, batch 1/242:	Discriminator: real loss 0.18314047157764435, fake loss 0.1878712773323059	Generator: loss 0.8994388580322266
# Epoch 47, batch 51/242:	Discriminator: real loss 0.19398042559623718, fake loss 0.20486488938331604	Generator: loss 0.9175788164138794
# Epoch 47, batch 101/242:	Discriminator: real loss 0.18596011400222778, fake loss 0.20252296328544617	Generator: loss 0.9564080238342285
# Epoch 47, batch 151/242:	Discriminator: real loss 0.19150495529174805, fake loss 0.18409261107444763	Generator: loss 0.9019054770469666
# Epoch 47, batch 201/242:	Discriminator: real loss 0.17327550053596497, fake loss 0.1865958571434021	Generator: loss 0.9412087798118591
# Epoch 48, batch 1/242:	Discriminator: real loss 0.2101682722568512, fake loss 0.18284764885902405	Generator: loss 0.9488025307655334
# Epoch 48, batch 51/242:	Discriminator: real loss 0.1983938068151474, fake loss 0.1925327032804489	Generator: loss 0.9169484972953796
# Epoch 48, batch 101/242:	Discriminator: real loss 0.19060127437114716, fake loss 0.16627830266952515	Generator: loss 0.9461641311645508
# Epoch 48, batch 151/242:	Discriminator: real loss 0.2138601541519165, fake loss 0.1990782618522644	Generator: loss 0.8846789002418518
# Epoch 48, batch 201/242:	Discriminator: real loss 0.18070825934410095, fake loss 0.20001950860023499	Generator: loss 0.9566353559494019
# Epoch 49, batch 1/242:	Discriminator: real loss 0.19479340314865112, fake loss 0.17115071415901184	Generator: loss 0.9336584210395813
# Epoch 49, batch 51/242:	Discriminator: real loss 0.1841532289981842, fake loss 0.21061554551124573	Generator: loss 0.9454275369644165
# Epoch 49, batch 101/242:	Discriminator: real loss 0.18545350432395935, fake loss 0.18431958556175232	Generator: loss 0.9235506653785706
# Epoch 49, batch 151/242:	Discriminator: real loss 0.17976295948028564, fake loss 0.19467167556285858	Generator: loss 0.9165023565292358
# Epoch 49, batch 201/242:	Discriminator: real loss 0.19045686721801758, fake loss 0.18956886231899261	Generator: loss 0.9270930886268616
# Epoch 50, batch 1/242:	Discriminator: real loss 0.1821567863225937, fake loss 0.18072764575481415	Generator: loss 0.903059720993042
# Epoch 50, batch 51/242:	Discriminator: real loss 0.19480475783348083, fake loss 0.1765887290239334	Generator: loss 0.9094331860542297
# Epoch 50, batch 101/242:	Discriminator: real loss 0.19598260521888733, fake loss 0.19123396277427673	Generator: loss 0.9267914891242981
# Epoch 50, batch 151/242:	Discriminator: real loss 0.2118675708770752, fake loss 0.1669042557477951	Generator: loss 0.9073975682258606
# Epoch 50, batch 201/242:	Discriminator: real loss 0.17889109253883362, fake loss 0.1832299530506134	Generator: loss 0.9078012704849243

# %%
def show_generated(examples, n, c):
  fig = plt.figure(figsize=(c, n))
  for i in range(n*c):
    img = fig.add_subplot(n, c, i+1)
    plt.axis('off')
    plt.imshow(examples[i,:,:,0], cmap='gray_r')
  plt.show()

n = 10
c = 62

model = load_model('generator.h5')
noise, _ = generate_latent_noise(latent_dim, n*c)
labs = np.asarray([x for _ in range(n) for x in range(c)])

X = model.predict([noise, labs])
# scale from [-1, 1] to [0, 1]
X = (X + 1) / 2.0
x = np.squeeze(X[0])
plt.imshow(x)

show_generated(X, n, c)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from google.colab import files

dflag = True
if dflag:
  #files.download('gan.h5')
  files.download('generator.h5')
  #files.download('discriminator.h5')
